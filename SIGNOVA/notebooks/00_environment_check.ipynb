# %% [markdown]
# # 00 — Environment & GPU Diagnostic
# Verifies hardware accelerator (NVIDIA RTX 3050), CUDA availability, and installed library versions.

# %%
import sys
import platform
print(f"Python: {sys.version}")
print(f"OS: {platform.system()} {platform.release()}")

# %%
# !python ../scripts/check_environment.py
