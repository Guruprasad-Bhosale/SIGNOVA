# %% [markdown]
# # 01 — Dataset Audit and Manifest Inspection
# Inspects local references to ISLTranslate and validates canonical manifest structures.

# %%
# !python ../scripts/inspect_dataset.py

# %%
import pandas as pd
df = pd.read_csv('../data/manifests/isltranslate_manifest.csv')
print(f"Total rows: {len(df)}")
print(df.head())
print(df['split'].value_counts())
