# %% [markdown]
# # 02 — Visualize Landmarks and Normalization
# Tests landmark extraction data structures and verifies spatial normalization mathematics.

# %%
import numpy as np
from signova.preprocessing.landmarks import HolisticLandmarkFrame
from signova.preprocessing.normalization import normalize_landmarks_frame

raw_sample = np.random.uniform(0.1, 0.9, size=(543, 3)).astype(np.float32)
norm_sample = normalize_landmarks_frame(raw_sample)
print(f"Raw landmark shape: {raw_sample.shape}")
print(f"Normalized landmark shape: {norm_sample.shape}")
